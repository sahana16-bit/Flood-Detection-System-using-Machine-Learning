# %% [markdown]
# <a href="https://colab.research.google.com/github/sahana16-bit/Flood-Detection-System-using-Machine-Learning/blob/main/Flood%20Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import joblib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %%
num_days = 365
dates = pd.date_range(start='2024-01-01', periods=num_days, freq='D')
rainfall_mm = np.random.gamma(2, 20, num_days)
drainage_efficiency = np.random.uniform(3, 9, num_days)

rainfall_status = pd.cut(rainfall_mm, bins=[0, 20, 50, 1000], labels=["Light", "Moderate", "Heavy"])

# %%
flood_risk_score = (rainfall_mm / 10) * 0.5 + (10 - drainage_efficiency) * 0.5
flood_occurrence = np.where(flood_risk_score > 4.5, "Yes", "No")

# %%
data = pd.DataFrame({
    "Date": dates,
    "Rainfall_mm": rainfall_mm,
    "Drainage_Efficiency": drainage_efficiency,
    "Rainfall_Status": rainfall_status,
    "Flood_Occurrence": flood_occurrence
})

# %%
total_days = len(data)
flood_days = (data["Flood_Occurrence"] == "Yes").sum()
heavy_rain_days = (data["Rainfall_Status"] == "Heavy").sum()
flood_percent = (flood_days / total_days) * 100

# %%
# Rainfall data for 3 stations
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug']
rainfall_data = pd.DataFrame({
    'Month': months,
    'Station 1': [50, 60, 80, 120, 100, 160, 220, 180],
    'Station 2': [55, 65, 90, 100, 130, 170, 240, 190],
    'Station 3': [40, 55, 70, 110, 120, 150, 210, 175]
})

# Temperature vs Humidity
weather_data = pd.DataFrame({
    'Temperature': [25, 28, 30, 27, 29, 31, 26],
    'Humidity': [75, 70, 65, 68, 72, 66, 80]
})

# %%
#Rainfall Analysis (Line Graph)

import matplotlib.pyplot as plt
import numpy as np

# -----------------------------
# 1️⃣ Rainfall Analysis (Line Graph)
# -----------------------------
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug']
station1 = [50, 60, 80, 120, 100, 160, 220, 180]
station2 = [55, 65, 90, 100, 130, 170, 240, 190]
station3 = [40, 55, 70, 110, 120, 150, 210, 175]

plt.figure(figsize=(8, 5))
plt.plot(months, station1, marker='o', label='Station 1')
plt.plot(months, station2, marker='o', label='Station 2')
plt.plot(months, station3, marker='o', label='Station 3')
plt.title("🌧️ Rainfall Analysis (Station-wise)")
plt.xlabel("Month")
plt.ylabel("Rainfall (mm)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-813186045.py:21: UserWarning: Glyph 127783 (\N{CLOUD WITH RAIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127783 (\N{CLOUD WITH RAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Temperature vs Humidity (Scatter Plot)

temperature = [25, 28, 30, 27, 29, 31, 26]
humidity = [75, 70, 65, 68, 72, 66, 80]

plt.figure(figsize=(6, 5))
plt.scatter(temperature, humidity, color='purple', s=80)
plt.title("🌡️ Temperature vs Humidity")
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-241037602.py:10: UserWarning: Glyph 127777 (\N{THERMOMETER}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127777 (\N{THERMOMETER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Flood Probability Distribution (Bar Chart)

flood_probability = 25  # Example probability from your screenshot
no_flood_probability = 100 - flood_probability

labels = ['No Flood', 'Flood']
values = [no_flood_probability, flood_probability]

plt.figure(figsize=(5, 5))
bars = plt.bar(labels, values, color=['#82ca9d', '#ff7f7f'])
plt.title("🌊 Flood Probability Distribution")
plt.ylabel("Probability (%)")
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 127754 (\N{WATER WAVE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127754 (\N{WATER WAVE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("\n" + "="*60)
print(" FLOOD DETECTION SUMMARY FOR CHENNAI (2024)")
print("="*60)
print(f" Total Days Recorded: {total_days}")
print(f"Heavy Rainfall Days: {heavy_rain_days}")
print(f" Flood Occurrence Days: {flood_days}")
print(f" Flood Likelihood: {flood_percent:.2f}%")
print("\n Interpretation:")
if flood_percent > 15:
    print("High risk of flooding — heavy rainfall and poor drainage are key factors.")
elif flood_percent > 5:
    print("Moderate risk — occasional floods during intense rainfall.")
else:
    print("Low risk — rainfall mostly within safe limits.")
print("="*60)
# Out:
# ...
#  FLOOD DETECTION SUMMARY FOR CHENNAI (2024)
# ...
#  Total Days Recorded: 365
# Heavy Rainfall Days: 99
#  Flood Occurrence Days: 116
#  Flood Likelihood: 31.78%
#
#  Interpretation:
# High risk of flooding — heavy rainfall and poor drainage are key factors.
# ...
